# %% [markdown]
# # Using K-Nearest Neighbors to predict the safety metric of an arbitrary car #
#
# ### We use a 5-featured set of over 1700 cars consisting of the number of doors, lug boot quality, maintenance and price to predict our target: safety ###
#
# ### The K-Nearest Neighbours learning algorithim classifies points based on its "k" nearest neighbors and their respective classes. ###

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn 
from sklearn.neighbors import KNeighborsClassifier
from sklearn import linear_model, preprocessing
## I did not add this: 
from sklearn.utils import shuffle

# %%
df = pd.read_csv("car.data", sep=",")

car_data = df

#Encode target labels with value between 0 and n-1 (n classes) 
le = preprocessing.LabelEncoder()  
#We do this for each column to ensure everything is encoded. We cannot perform computations on string data, must be numerical in this case: 

buying = le.fit_transform(list(car_data["buying"]))
maint = le.fit_transform(list(car_data["maint"]))
door = le.fit_transform(list(car_data["door"]))
persons = le.fit_transform(list(car_data["persons"]))
lug_boot = le.fit_transform(list(car_data["lug_boot"]))
safety = le.fit_transform(list(car_data["safety"]))
cls = le.fit_transform(list(car_data["class"]))


predict = "class"
#data:
X = list(zip(buying,maint,door,persons,lug_boot,safety))
y = list(cls)

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size=0.1)

# %%
#Visualizing shapes
print(f" Training x is a {len(x_train)} x {len(x_train[0])} matrix\n")
print(f" Training y is a {len(y_train)} vector\n")
print(f" Testing x is a {len(x_test)} x {len(x_test[0])} matrix\n")
print(f" Testing y is a {len(y_test)} vector\n")
# Out:
#  Training x is a 1555 x 6 matrix
#
#  Training y is a 1555 vector
#
#  Testing x is a 173 x 6 matrix
#
#  Testing y is a 173 vector

# %%
# Define the Model:
model = KNeighborsClassifier(n_neighbors=7)
#Fit the model to some training set: 
model.fit(x_train, y_train)
#Test model on the test sets 
acc = model.score(x_test, y_test)
print(acc)
# Out:
# 0.976878612716763

# %%
# predict data 

predicted = model.predict(x_test)
names =["unacceptable","acceptable","good","very good"]


for i in range(len(predicted)): 
    print(f"Predicted: {names[predicted[i]]} Data: {x_test[i]}, Actual: {names[y_test[i]]}\n")
    n = model.kneighbors([x_test[i]],7,True)
    print(f"Distances:{n[0]}\n Indices: {n[1]}\n")
# Out:
# Predicted: good Data: (np.int64(3), np.int64(3), np.int64(3), np.int64(1), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 231  908 1435 1150 1243  861  447]]
#
# Predicted: unacceptable Data: (np.int64(2), np.int64(3), np.int64(3), np.int64(1), np.int64(0), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 861  912  858 1150  679  178  101]]
#
# Predicted: unacceptable Data: (np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(2), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 176   47 1349  983  778  469  623]]
#
# Predicted: good Data: (np.int64(3), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[1330 1449  859  904 1375 1185 1160]]
#
# Predicted: good Data: (np.int64(3), np.int64(2), np.int64(0), np.int64(0), np.int64(0), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[  93 1416  504  749 1322  257 1449]]
#
# Predicted: unacceptable Data: (np.int64(3), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1493  159  666  189   84 1449  904]]
#
# Predicted: unacceptable Data: (np.int64(3), np.int64(1), np.int64(2), np.int64(2), np.int64(0), np.int64(2)), Actual: unacceptable
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[1060  316 1281 1421  801  425 1393]]
#
# Predicted: unacceptable Data: (np.int64(2), np.int64(3), np.int64(2), np.int64(2), np.int64(0), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[891 699 816 751 236 679 178]]
#
# Predicted: good Data: (np.int64(3), np.int64(3), np.int64(3), np.int64(2), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 473 1301  783  139  566 1223  163]]
#
# Predicted: good Data: (np.int64(1), np.int64(2), np.int64(0), np.int64(0), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1389  202 1300 1111 1068  286  928]]
#
# Predicted: good Data: (np.int64(1), np.int64(3), np.int64(1), np.int64(0), np.int64(0), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1419  177  953 1307  394  157 1055]]
#
# Predicted: unacceptable Data: (np.int64(0), np.int64(0), np.int64(2), np.int64(1), np.int64(1), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1349 1520  966 1412  849  199  623]]
#
# Predicted: good Data: (np.int64(2), np.int64(1), np.int64(2), np.int64(0), np.int64(0), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1366  501  484 1545  279 1473  124]]
#
# Predicted: good Data: (np.int64(3), np.int64(3), np.int64(3), np.int64(2), np.int64(0), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 489  566  148  391    5 1434  358]]
#
# Predicted: unacceptable Data: (np.int64(3), np.int64(1), np.int64(0), np.int64(2), np.int64(0), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 278  131 1493  577 1449  661 1554]]
#
# Predicted: unacceptable Data: (np.int64(0), np.int64(2), np.int64(2), np.int64(2), np.int64(1), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1021 1492  772 1361   53 1020  289]]
#
# Predicted: good Data: (np.int64(2), np.int64(3), np.int64(1), np.int64(1), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1408  654  714 1548  580 1144  401]]
#
# Predicted: good Data: (np.int64(1), np.int64(3), np.int64(0), np.int64(2), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 740  114  938 1528  990  110  142]]
#
# Predicted: unacceptable Data: (np.int64(0), np.int64(2), np.int64(3), np.int64(2), np.int64(0), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1020  986  989  284  434   53  475]]
#
# Predicted: good Data: (np.int64(2), np.int64(0), np.int64(3), np.int64(0), np.int64(0), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 521  300  217 1473  750  126  817]]
#
# Predicted: good Data: (np.int64(2), np.int64(3), np.int64(3), np.int64(0), np.int64(0), np.int64(2)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.41421356
#   1.41421356]]
#  Indices: [[ 584  149  779  766 1146  194  101]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(0), np.int64(0), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.41421356
#   1.41421356]]
#  Indices: [[  55  487  460  296 1310  268  138]]
#
# Predicted: good Data: (np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 882 1183  631  218  377 1095  660]]
#
# Predicted: good Data: (np.int64(2), np.int64(2), np.int64(1), np.int64(1), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1227 1049  937  343  698 1001  597]]
#
# Predicted: good Data: (np.int64(1), np.int64(1), np.int64(3), np.int64(0), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[1451  186 1256 1452  824  803   15]]
#
# Predicted: unacceptable Data: (np.int64(2), np.int64(0), np.int64(0), np.int64(2), np.int64(1), np.int64(0)), Actual: unacceptable
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[851 673 433 634 770 738 311]]
#
# Predicted: good Data: (np.int64(3), np.int64(3), np.int64(2), np.int64(1), np.int64(1), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1294 1430  659 1016  575  478  147]]
#
# Predicted: good Data: (np.int64(3), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 507   30 1160  773  814 1490  321]]
#
# Predicted: good Data: (np.int64(2), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1417 1139 1357 1446 1306  535  127]]
#
# Predicted: acceptable Data: (np.int64(2), np.int64(1), np.int64(2), np.int64(2), np.int64(0), np.int64(2)), Actual: acceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[448 816 900 843 573 857 287]]
#
# Predicted: unacceptable Data: (np.int64(0), np.int64(0), np.int64(1), np.int64(2), np.int64(0), np.int64(2)), Actual: unacceptable
#
# Distances:[[1.         1.         1.         1.         1.         1.41421356
#   1.41421356]]
#  Indices: [[ 942  618 1333  722  993  613  744]]
#
# Predicted: good Data: (np.int64(2), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 911  540  602 1273  180  244   29]]
#
# Predicted: unacceptable Data: (np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(2), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1359 1374 1341 1172  258  875  363]]
#
# Predicted: good Data: (np.int64(1), np.int64(2), np.int64(3), np.int64(0), np.int64(1), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 726 1097  704 1256  429   21  359]]
#
# Predicted: good Data: (np.int64(1), np.int64(2), np.int64(1), np.int64(0), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 122  470  518 1300  373  385  286]]
#
# Predicted: good Data: (np.int64(3), np.int64(2), np.int64(0), np.int64(0), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 711 1040 1463  749 1322  610  502]]
#
# Predicted: good Data: (np.int64(1), np.int64(3), np.int64(0), np.int64(2), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1364 1193  616 1539  239 1249  583]]
#
# Predicted: good Data: (np.int64(3), np.int64(2), np.int64(2), np.int64(1), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 967 1252  303  537  794 1388 1026]]
#
# Predicted: good Data: (np.int64(1), np.int64(2), np.int64(0), np.int64(2), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 990 1528  976  140   79 1157  115]]
#
# Predicted: good Data: (np.int64(1), np.int64(3), np.int64(0), np.int64(1), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1091  151  225 1401  277 1319  110]]
#
# Predicted: good Data: (np.int64(0), np.int64(1), np.int64(3), np.int64(0), np.int64(0), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1211 1087 1221 1317 1441 1470  107]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(2)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.41421356
#   1.41421356]]
#  Indices: [[1173  544  514   69  570 1233  503]]
#
# Predicted: unacceptable Data: (np.int64(1), np.int64(1), np.int64(2), np.int64(1), np.int64(2), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 309  995 1066  243  578 1158  405]]
#
# Predicted: good Data: (np.int64(0), np.int64(0), np.int64(3), np.int64(0), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.41421356
#   1.41421356]]
#  Indices: [[1451 1071  994 1208  824 1277 1077]]
#
# Predicted: good Data: (np.int64(2), np.int64(0), np.int64(0), np.int64(0), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[1450  296  460  215  387 1167  695]]
#
# Predicted: good Data: (np.int64(1), np.int64(2), np.int64(0), np.int64(1), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 830 1498 1009 1134  895  583  369]]
#
# Predicted: good Data: (np.int64(2), np.int64(2), np.int64(1), np.int64(2), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 496 1422  896  477 1098 1112 1275]]
#
# Predicted: good Data: (np.int64(0), np.int64(0), np.int64(1), np.int64(2), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 375 1426 1496   27  715  744 1385]]
#
# Predicted: unacceptable Data: (np.int64(2), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 770  634  404  911  180  567 1103]]
#
# Predicted: good Data: (np.int64(3), np.int64(2), np.int64(2), np.int64(0), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 524  860  705 1058  885  530  417]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(0), np.int64(1), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.41421356
#   1.41421356]]
#  Indices: [[ 672 1414  674  268  572  460  248]]
#
# Predicted: good Data: (np.int64(3), np.int64(2), np.int64(1), np.int64(1), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1405 1437 1018 1431  380  666 1032]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(0), np.int64(2), np.int64(1), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.41421356
#   1.41421356]]
#  Indices: [[ 661 1554  797   71 1402  294  731]]
#
# Predicted: good Data: (np.int64(1), np.int64(0), np.int64(2), np.int64(2), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 549 1335 1363 1385 1108 1426  693]]
#
# Predicted: unacceptable Data: (np.int64(2), np.int64(2), np.int64(1), np.int64(2), np.int64(1), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 576  246  863 1422  365  477  213]]
#
# Predicted: good Data: (np.int64(0), np.int64(3), np.int64(0), np.int64(2), np.int64(1), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 644 1326  799  616  614  802  239]]
#
# Predicted: good Data: (np.int64(0), np.int64(0), np.int64(3), np.int64(0), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[   7  939 1481  254 1077 1477 1316]]
#
# Predicted: good Data: (np.int64(0), np.int64(2), np.int64(3), np.int64(0), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1299  227 1383 1513  958 1305 1087]]
#
# Predicted: good Data: (np.int64(2), np.int64(0), np.int64(3), np.int64(1), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1398 1182 1042  964  627  397  607]]
#
# Predicted: good Data: (np.int64(0), np.int64(3), np.int64(0), np.int64(1), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 614 1236   95  802  420  419   17]]
#
# Predicted: unacceptable Data: (np.int64(2), np.int64(2), np.int64(3), np.int64(1), np.int64(1), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[760 959 130 861  23 101 170]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(2), np.int64(1), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 515  432 1168  106  105  557  864]]
#
# Predicted: good Data: (np.int64(2), np.int64(3), np.int64(3), np.int64(0), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1061  280  899 1391  858  909   67]]
#
# Predicted: good Data: (np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(1), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[  37   99  820 1068  928  973  374]]
#
# Predicted: good Data: (np.int64(2), np.int64(3), np.int64(2), np.int64(1), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1458  714 1019  413  245  206  654]]
#
# Predicted: acceptable Data: (np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0)), Actual: acceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 270  830  854 1359  456 1341  529]]
#
# Predicted: good Data: (np.int64(0), np.int64(0), np.int64(0), np.int64(2), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.41421356
#   1.41421356]]
#  Indices: [[1394  379 1172 1283 1374 1491    0]]
#
# Predicted: good Data: (np.int64(3), np.int64(3), np.int64(3), np.int64(1), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 850 1294 1114 1214  558 1149  589]]
#
# Predicted: good Data: (np.int64(0), np.int64(1), np.int64(0), np.int64(2), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[1213  744  825 1373  715  815 1420]]
#
# Predicted: good Data: (np.int64(2), np.int64(3), np.int64(0), np.int64(1), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1448  713  332 1548  925   16  714]]
#
# Predicted: good Data: (np.int64(3), np.int64(1), np.int64(3), np.int64(0), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 885  921 1270 1298 1067  860  403]]
#
# Predicted: unacceptable Data: (np.int64(0), np.int64(1), np.int64(2), np.int64(2), np.int64(2), np.int64(0)), Actual: unacceptable
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 881  355  960  121 1423  772  690]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(2), np.int64(1), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[  70  664  545  288  262 1046   66]]
#
# Predicted: unacceptable Data: (np.int64(1), np.int64(2), np.int64(0), np.int64(1), np.int64(0), np.int64(0)), Actual: very good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1135  789 1009 1190  212  830  458]]
#
# Predicted: good Data: (np.int64(0), np.int64(0), np.int64(0), np.int64(2), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[   0 1263  950   12 1491 1526   91]]
#
# Predicted: unacceptable Data: (np.int64(2), np.int64(0), np.int64(2), np.int64(1), np.int64(1), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1232  798 1304 1486  345  817  541]]
#
# Predicted: good Data: (np.int64(3), np.int64(1), np.int64(2), np.int64(1), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 998  223 1270 1342  885 1393  557]]
#
# Predicted: good Data: (np.int64(1), np.int64(1), np.int64(2), np.int64(0), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 219  568 1066 1120  561  309  488]]
#
# Predicted: unacceptable Data: (np.int64(3), np.int64(2), np.int64(0), np.int64(2), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[  31 1517 1438 1033 1328  552  532]]
#
# Predicted: good Data: (np.int64(3), np.int64(1), np.int64(3), np.int64(1), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1388 1272  999 1259  792 1007   73]]
#
# Predicted: good Data: (np.int64(1), np.int64(2), np.int64(0), np.int64(0), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1153 1443  895 1498  430   62  208]]
#
# Predicted: good Data: (np.int64(1), np.int64(0), np.int64(0), np.int64(2), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1385  844 1162  439 1487  825  715]]
#
# Predicted: unacceptable Data: (np.int64(1), np.int64(2), np.int64(2), np.int64(1), np.int64(2), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 997 1187  264 1028   98  897   11]]
#
# Predicted: good Data: (np.int64(1), np.int64(2), np.int64(2), np.int64(0), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1187 1513  264 1383   33  481 1153]]
#
# Predicted: good Data: (np.int64(3), np.int64(1), np.int64(3), np.int64(0), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1500  253  626  650  150  686  503]]
#
# Predicted: unacceptable Data: (np.int64(0), np.int64(1), np.int64(0), np.int64(2), np.int64(0), np.int64(0)), Actual: unacceptable
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 657  204  329  495   20 1128 1373]]
#
# Predicted: good Data: (np.int64(3), np.int64(2), np.int64(0), np.int64(2), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 734  753  209 1503  865  724  298]]
#
# Predicted: good Data: (np.int64(3), np.int64(3), np.int64(1), np.int64(1), np.int64(0), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1405  210 1296  926  620  492  380]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(3), np.int64(2), np.int64(0), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.41421356
#   1.41421356]]
#  Indices: [[ 606 1235 1104 1083  621 1151  269]]
#
# Predicted: good Data: (np.int64(1), np.int64(1), np.int64(2), np.int64(1), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1246  755 1247 1108  956   80  617]]
#
# Predicted: unacceptable Data: (np.int64(1), np.int64(2), np.int64(1), np.int64(2), np.int64(1), np.int64(2)), Actual: acceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[   8  324  807 1499  546 1157   79]]
#
# Predicted: good Data: (np.int64(2), np.int64(2), np.int64(1), np.int64(0), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 320  246 1258  342  136 1116  903]]
#
# Predicted: good Data: (np.int64(3), np.int64(3), np.int64(1), np.int64(2), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 522 1504  587 1334 1501 1220  633]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1500  992  288 1057   66 1381  503]]
#
# Predicted: good Data: (np.int64(2), np.int64(3), np.int64(2), np.int64(0), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 175  624 1279  728 1038 1287  426]]
#
# Predicted: good Data: (np.int64(2), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1544  138  535  127 1180 1523  156]]
#
# Predicted: good Data: (np.int64(0), np.int64(1), np.int64(3), np.int64(0), np.int64(0), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 190 1474  203 1529  648 1441   36]]
#
# Predicted: good Data: (np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[1232  817  787   22 1358 1409  521]]
#
# Predicted: good Data: (np.int64(0), np.int64(3), np.int64(0), np.int64(0), np.int64(1), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[533 802 733  95 745 308 820]]
#
# Predicted: good Data: (np.int64(2), np.int64(0), np.int64(0), np.int64(2), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 224   71  103  776 1538 1172  293]]
#
# Predicted: unacceptable Data: (np.int64(0), np.int64(2), np.int64(1), np.int64(2), np.int64(0), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 630 1020 1128  550 1127  510  289]]
#
# Predicted: unacceptable Data: (np.int64(0), np.int64(0), np.int64(2), np.int64(2), np.int64(2), np.int64(0)), Actual: unacceptable
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 399 1006 1036 1277  690  379  137]]
#
# Predicted: good Data: (np.int64(2), np.int64(2), np.int64(3), np.int64(0), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 559  959  238  899   67  130 1027]]
#
# Predicted: good Data: (np.int64(0), np.int64(3), np.int64(2), np.int64(1), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 554 1148 1461 1202   11   49  723]]
#
# Predicted: good Data: (np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1225  968 1012  933  366   99  867]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(2)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 992  346  261  774 1347  892   87]]
#
# Predicted: good Data: (np.int64(0), np.int64(3), np.int64(0), np.int64(1), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 709  915  277  225  737   10 1424]]
#
# Predicted: good Data: (np.int64(1), np.int64(3), np.int64(3), np.int64(0), np.int64(1), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[652 167 263 701 835 727 112]]
#
# Predicted: unacceptable Data: (np.int64(1), np.int64(3), np.int64(0), np.int64(2), np.int64(0), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1249 1524  616  360 1135  789  799]]
#
# Predicted: unacceptable Data: (np.int64(0), np.int64(2), np.int64(3), np.int64(2), np.int64(0), np.int64(2)), Actual: unacceptable
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[162 120 936 434 563  72 427]]
#
# Predicted: good Data: (np.int64(3), np.int64(3), np.int64(1), np.int64(1), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1205 1501 1049 1334  886  285 1346]]
#
# Predicted: unacceptable Data: (np.int64(3), np.int64(2), np.int64(1), np.int64(2), np.int64(1), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 353  237  878 1517 1253 1033 1396]]
#
# Predicted: good Data: (np.int64(2), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 597  255  567  911  330 1156   29]]
#
# Predicted: good Data: (np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1250  334  581 1267  293  687 1217]]
#
# Predicted: good Data: (np.int64(1), np.int64(3), np.int64(1), np.int64(1), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[394 752 151 953 730  10 225]]
#
# Predicted: good Data: (np.int64(0), np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1099    0 1017 1491   20  523  588]]
#
# Predicted: unacceptable Data: (np.int64(0), np.int64(1), np.int64(1), np.int64(2), np.int64(0), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 613  182  398  119 1213  744  485]]
#
# Predicted: good Data: (np.int64(2), np.int64(0), np.int64(1), np.int64(0), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1215  354 1336 1549 1180   96  695]]
#
# Predicted: unacceptable Data: (np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(0), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 602  448  540 1415  843  581 1231]]
#
# Predicted: good Data: (np.int64(2), np.int64(3), np.int64(3), np.int64(1), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 362   59 1551 1243  974  381  861]]
#
# Predicted: good Data: (np.int64(1), np.int64(1), np.int64(2), np.int64(0), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1521  595 1101  795   15 1418  929]]
#
# Predicted: acceptable Data: (np.int64(1), np.int64(1), np.int64(2), np.int64(2), np.int64(2), np.int64(0)), Actual: acceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1276   81 1101  818   76 1432 1036]]
#
# Predicted: good Data: (np.int64(3), np.int64(1), np.int64(0), np.int64(0), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 502  215 1310  460  497  328  216]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(2), np.int64(2), np.int64(0), np.int64(2)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 544 1525  448 1264 1123 1415 1046]]
#
# Predicted: good Data: (np.int64(0), np.int64(3), np.int64(3), np.int64(1), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[669 913  59  75 763 356  49]]
#
# Predicted: good Data: (np.int64(3), np.int64(2), np.int64(2), np.int64(2), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 735  653  524 1220  762  998  571]]
#
# Predicted: good Data: (np.int64(2), np.int64(0), np.int64(3), np.int64(0), np.int64(0), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[547 161 386 570 750 259  69]]
#
# Predicted: good Data: (np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 541  695  647 1085 1232  354 1064]]
#
# Predicted: acceptable Data: (np.int64(1), np.int64(2), np.int64(3), np.int64(2), np.int64(0), np.int64(2)), Actual: acceptable
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 383  427  333   58  221 1550  388]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(3), np.int64(2), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 887 1182  754 1365  889 1042 1264]]
#
# Predicted: good Data: (np.int64(3), np.int64(3), np.int64(1), np.int64(2), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 620 1047  926  576  769  633  451]]
#
# Predicted: good Data: (np.int64(0), np.int64(2), np.int64(2), np.int64(0), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1383 1299  556 1226  304 1176   33]]
#
# Predicted: good Data: (np.int64(2), np.int64(3), np.int64(2), np.int64(0), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1279 1355 1251 1287  909  238   67]]
#
# Predicted: unacceptable Data: (np.int64(1), np.int64(0), np.int64(3), np.int64(1), np.int64(2), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1325 1337  201 1071 1451  186   46]]
#
# Predicted: acceptable Data: (np.int64(1), np.int64(2), np.int64(1), np.int64(1), np.int64(1), np.int64(0)), Actual: acceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1195 1425  775 1203  212  830  369]]
#
# Predicted: unacceptable Data: (np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 968 1442  867 1200  565  805  200]]
#
# Predicted: good Data: (np.int64(0), np.int64(2), np.int64(2), np.int64(2), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1020 1361  563 1254  434  510  132]]
#
# Predicted: good Data: (np.int64(3), np.int64(2), np.int64(0), np.int64(2), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[1504  298  555  271  522   40 1516]]
#
# Predicted: very good Data: (np.int64(1), np.int64(0), np.int64(2), np.int64(2), np.int64(0), np.int64(0)), Actual: very good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 917 1206  832   83  195 1497  137]]
#
# Predicted: good Data: (np.int64(3), np.int64(2), np.int64(1), np.int64(1), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1018  633  229 1405 1130  620 1212]]
#
# Predicted: good Data: (np.int64(3), np.int64(3), np.int64(0), np.int64(2), np.int64(0), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 131 1121  457 1524 1406 1518 1136]]
#
# Predicted: good Data: (np.int64(1), np.int64(2), np.int64(3), np.int64(1), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 897 1028  691  949  472   54  325]]
#
# Predicted: unacceptable Data: (np.int64(1), np.int64(3), np.int64(3), np.int64(2), np.int64(0), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 475  489 1170 1459  777  982  284]]
#
# Predicted: unacceptable Data: (np.int64(1), np.int64(0), np.int64(3), np.int64(2), np.int64(0), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1072  480  549  333 1363  786  846]]
#
# Predicted: good Data: (np.int64(1), np.int64(1), np.int64(3), np.int64(2), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1108  755  893  333  272  549  102]]
#
# Predicted: good Data: (np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1089 1191 1070  219 1178 1210  267]]
#
# Predicted: good Data: (np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1323 1068 1225  202 1453   99  494]]
#
# Predicted: good Data: (np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1424  277  230 1462  612  374   37]]
#
# Predicted: unacceptable Data: (np.int64(2), np.int64(3), np.int64(0), np.int64(1), np.int64(1), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 918 1136  327 1404  171  804   94]]
#
# Predicted: good Data: (np.int64(0), np.int64(2), np.int64(2), np.int64(0), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[   3 1175  810 1339  385 1242   90]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(1), np.int64(1), np.int64(2), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 223  557 1267 1217 1196  487  432]]
#
# Predicted: unacceptable Data: (np.int64(0), np.int64(2), np.int64(2), np.int64(1), np.int64(2), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 315 1339  772 1021  179  810   28]]
#
# Predicted: good Data: (np.int64(2), np.int64(2), np.int64(2), np.int64(0), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1379  945  455 1133  444 1313  647]]
#
# Predicted: good Data: (np.int64(1), np.int64(3), np.int64(3), np.int64(1), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 833 1479   75  975   59  748  423]]
#
# Predicted: good Data: (np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 218  199 1095  862  349 1489  260]]
#
# Predicted: unacceptable Data: (np.int64(2), np.int64(2), np.int64(3), np.int64(2), np.int64(0), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 816 1164  679 1291  101  760  857]]
#
# Predicted: unacceptable Data: (np.int64(1), np.int64(3), np.int64(2), np.int64(1), np.int64(0), np.int64(2)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 454 1510  525  912  242  368  752]]
#
# Predicted: good Data: (np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1376  882  668 1467  409 1095 1440]]
#
# Predicted: good Data: (np.int64(2), np.int64(1), np.int64(3), np.int64(1), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1534  984 1327 1122  964 1398  527]]
#
# Predicted: good Data: (np.int64(3), np.int64(1), np.int64(2), np.int64(1), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 262  338 1143 1469   56  403  273]]
#
# Predicted: good Data: (np.int64(3), np.int64(3), np.int64(2), np.int64(2), np.int64(0), np.int64(2)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 697 1371 1047 1512  425  926  891]]
#
# Predicted: good Data: (np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[631  15 363 409 795 258 882]]
#
# Predicted: good Data: (np.int64(2), np.int64(3), np.int64(1), np.int64(0), np.int64(1), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 452  135  728  804  739 1078  171]]
#
# Predicted: good Data: (np.int64(0), np.int64(2), np.int64(1), np.int64(1), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1195 1527  369 1228  438  304  340]]
#
# Predicted: good Data: (np.int64(1), np.int64(2), np.int64(3), np.int64(0), np.int64(2), np.int64(0)), Actual: good
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[  54  835  949   64  595 1379  179]]
#
# Predicted: good Data: (np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(0), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1497 1360 1219  591 1010  629  688]]
#
# Predicted: unacceptable Data: (np.int64(3), np.int64(1), np.int64(3), np.int64(2), np.int64(0), np.int64(0)), Actual: unacceptable
#
# Distances:[[1.         1.         1.         1.         1.         1.
#   1.41421356]]
#  Indices: [[ 790 1282  999 1259  670 1434 1073]]
#
# Predicted: good Data: (np.int64(3), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(2)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[ 265 1116  542  992 1130  261  856]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(3), np.int64(0), np.int64(2), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1168  710 1298 1540 1067   39  515]]
#
# Predicted: good Data: (np.int64(3), np.int64(3), np.int64(3), np.int64(0), np.int64(1), np.int64(1)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1260   68  453 1391  266  231   67]]
#
# Predicted: good Data: (np.int64(3), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0)), Actual: good
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1161  770 1044 1230  474 1065  855]]
#
# Predicted: unacceptable Data: (np.int64(2), np.int64(3), np.int64(0), np.int64(2), np.int64(1), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1478  616 1193 1518  827 1524 1074]]
#
# Predicted: unacceptable Data: (np.int64(2), np.int64(3), np.int64(2), np.int64(2), np.int64(2), np.int64(0)), Actual: unacceptable
#
# Distances:[[1. 1. 1. 1. 1. 1. 1.]]
#  Indices: [[1284  116  725 1223  508  473  426]]
